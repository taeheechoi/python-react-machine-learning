# %%
import easyocr
reader = easyocr.Reader(['ko', 'en'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('image/welcome.jpg')

plt.figure(figsize=(8, 8))
print(plt)
plt.imshow(img[:, :, 0])
plt.axis('off')
plt.show()
# Out:
# <module 'matplotlib.pyplot' from 'd:\\Developments\\python-react-machine-learning\\backend\\venv\\lib\\site-packages\\matplotlib\\pyplot.py'>
